# %%
import numpy as np 
import pandas as pd
import sys
from sklearn.tree import DecisionTreeClassifier

# %%
my_data = pd.read_csv("training_2.csv", delimiter=",")

# %%
#sys.getsizeof(my_data)/(1024*1024*1024)
#np.unique(my_data["PROV_B_M_A_STATE_NAME"])

# %%
X = my_data[['ENTITY_TYPE_CODE','PROVIDERNAME', 'PROV_B_M_A_STATE_NAME', 'PROV_B_M_A_POSTAL_CODE', 'SPECDESC','PROV_B_P_B_P_LOC_ADD_TEL_NUM','PROV_B_M_A_CITY_NAME','PRIMARY_TAXONOMY']].values
#X[0:3]

# %%
from sklearn import preprocessing

le_PROVIDERNAME = preprocessing.LabelEncoder()
le_PROVIDERNAME.fit(np.unique(my_data["PROVIDERNAME"]))
X[:,1] = le_PROVIDERNAME.transform(X[:,1]) 

le_STATE_NAME = preprocessing.LabelEncoder()
le_STATE_NAME.fit(np.unique(my_data["PROV_B_M_A_STATE_NAME"]))
X[:,2] = le_STATE_NAME.transform(X[:,2]) 

le_SPECDESC = preprocessing.LabelEncoder()
le_SPECDESC.fit(np.unique(my_data["SPECDESC"]))
X[:,4] = le_SPECDESC.transform(X[:,4]) 

le_CITY_NAME = preprocessing.LabelEncoder()
le_CITY_NAME.fit(np.unique(my_data["PROV_B_M_A_CITY_NAME"]))
X[:,6] = le_CITY_NAME.transform(X[:,6]) 


le_PRIMARY_TAXONOMY = preprocessing.LabelEncoder()
le_PRIMARY_TAXONOMY.fit(np.unique(my_data["PRIMARY_TAXONOMY"]))
X[:,7] = le_PRIMARY_TAXONOMY.transform(X[:,7])

# %%
#X[0:100]

# %%
y = my_data["NPI"]
y[0:5]
# Out:
# 0    1396819231
# 1    1194890707
# 2    1003981614
# 3    1912072521
# 4    1992870505
# Name: NPI, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)
X_trainset
# Out:
# array([[1, 47, 21, ..., 4193857755, 43, 21],
#        [1, 47, 21, ..., 4193857755, 43, 21],
#        [2, 0, 2, ..., 3238782660, 25, 29],
#        ...,
#        [2, 2, 0, ..., 5053400700, 0, 31],
#        [0, 38, 17, ..., 2523553177, 17, 2],
#        [2, 45, 0, ..., 4172350707, 28, 10]], dtype=object)

# %%
X_trainset.shape
# Out:
# (2377, 8)

# %%
y_trainset.shape
# Out:
# (2377,)

# %%
npiTree = DecisionTreeClassifier(criterion="entropy", max_depth = 5)
npiTree # it shows the default parameters
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
npiTree.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predTree = npiTree.predict(X_testset)

# %%
print (predTree [0:5])
print (y_testset [0:5])
# Out:
# [1790850303 1144395757 1144395757 1427122274 1295800811]
# 1092    1194890715
# 894     1033283890
# 1444    1033283890
# 972     1790859544
# 1631    1295800811
# Name: NPI, dtype: int64

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_testset, predTree))
# Out:
# DecisionTrees's Accuracy:  0.5976447497546614

# %%
np.take(my_data,np.random.permutation(my_data.shape[0]),axis=0)
# Out:
#              NPI                          PROVIDERNAME  ENTITY_TYPE_CODE  \
# 735   1922173541                     MCGEE, JAMES MATT                 1
# 2935  1053485896                                     0                 1
# 625   1518031368                JONES, STEPHEN MATTHEW                 0
# 2076  1164597779                                     0                 1
# 3127  1023183647                      PALMATIER, JANET                 1
# 2068  1396819231                                     0                 1
# 2180  1841365467   ADIRONDACK AUDIOLOGY ASSOCIATES, PC                 2
# 2154  1265507875                      YOUNG, JOSEPHINE                 1
# 2090  1982778734                                     0                 1
# 1912  1336213180                   FALDEN, ALLISON ANN                 1
# 780   1578638193           HARTMAN, AMANDA GRACE SCOTT                 1
# 470   1780758524          SMITH-FORBES, ENRIQUE VICTOR                 1
# 3273  1932274552                                     0                 1
# 1127  1396810917                                     0                 1
# 2576  1205901824                 ANCHORING LIGHT, INC.                 2
# 1921  1487729000               BEHAR-HORWITZ, LYNDA M.                 1
# 2574  1336213180                   FALDEN, ALLISON ANN                 1
# 1826  1396810917                  WEBSTER, JOHN THOMAS                 0
# 1354  1801961412  DEPENDABLE CARE TRANSPORTATION, INC.                 0
# 60    1790850303                   WEINGARTEN, RANDALL                 1
# 1996  1760556526                                     0                 1
# 3236  1013082635                      AXEL, JONATHAN P                 1
# 1223  1992870505                                     0                 1
# 760   1851466460                     BADGE, JAMES JOHN                 1
# 2543  1396819231            GUSKY-SHARP, KATHLEEN NONE                 1
# 16    1760557375     CASCADE MEDICAL TESTING LAB, INC.                 2
# 403   1750456372                                     0                 1
# 3231  1669547287                          MASRI, ELIAS                 1
# 1517  1053485896                         VO, CHRISTINE                 1
# 815   1780758524          SMITH-FORBES, ENRIQUE VICTOR                 0
# ...          ...                                   ...               ...
# 2661  1124193735                SCHMIT, EDWARD CHARLES                 0
# 1169  1780758524                                     0                 1
# 26    1427122274           STEWART G WILLOUGHBY DDS PC                 2
# 825   1023183647                      PALMATIER, JANET                 0
# 675   1518031368                JONES, STEPHEN MATTHEW                 1
# 221   1669547287                          MASRI, ELIAS                 1
# 3339  1851465611                 FISCHER, CINDY JOLENE                 1
# 1379  1023183647                                     0                 1
# 1014  1396810917                  WEBSTER, JOHN THOMAS                 1
# 2931  1124193735                                     0                 1
# 2807  1790850303                                     0                 1
# 603   1912072521                    JAFORD ENTERPRISES                 0
# 1658  1124193735                SCHMIT, EDWARD CHARLES                 0
# 2109  1740355361                                     0                 1
# 2315  1679648281                       DETTMER, ROBERT                 0
# 2480  1295800811                    RUTAR, STACIE HOPE                 1
# 1343  1124192984                    ROBERTSON, BETTY P                 1
# 672   1982778734                       RAND, BECKY MAY                 1
# 2811  1124193735                                     0                 1
# 1121  1982778734                                     0                 1
# 1712  1124193735                SCHMIT, EDWARD CHARLES                 1
# 456   1265507875                      YOUNG, JOSEPHINE                 1
# 871   1982778734                       RAND, BECKY MAY                 1
# 2547  1396819231            GUSKY-SHARP, KATHLEEN NONE                 1
# 1138  1013082635                                     0                 1
# 3092  1033283890               GARRIDO, SONIA GRIMALDO                 1
# 1501  1003981614                    MONIKA RUKUS, INC.                 2
# 61    1326113937                          GOLDMAN, IRA                 1
# 1436  1295800811                    RUTAR, STACIE HOPE                 1
# 506   1265507875                      YOUNG, JOSEPHINE                 0
#
#                  P_O_N_LEGAL_BUSINESS_NAME             P_F_L_B_M_ADDRESS  \
# 735                                    NaN            2827 BRANSFORD AVE
# 2935                                   NaN          15721 POINSETTIA WAY
# 625                                    NaN         16 W MISSION ST STE V
# 2076                                   NaN                1932 SW 3RD ST
# 3127                                   NaN               11414 W PARK PL
# 2068                                   NaN             105 VISTA VIEW DR
# 2180   ADIRONDACK AUDIOLOGY ASSOCIATES, PC  356 MOUNTAIN VIEW DR STE 101
# 2154                                   NaN              14711 NE 29TH PL
# 2090                                   NaN               33923 124 AVE N
# 1912                                   NaN              880 A1A N STE 13
# 780                                    NaN                    530 OAK ST
# 470                                    NaN                1994 BRAGET ST
# 3273                                   NaN                293 CASTLE AVE
# 1127                                   NaN               1614 S BYRNE RD
# 2576                 ANCHORING LIGHT, INC.   6100 UPTOWN BLVD NE STE 650
# 1921                                   NaN          100 E IRVING PARK RD
# 2574                                   NaN              880 A1A N STE 13
# 1826                                   NaN               1614 S BYRNE RD
# 1354  DEPENDABLE CARE TRANSPORTATION, INC.        639 N FAIRFAX AVE FL 2
# 60                                     NaN            945 MIDDLEFIELD RD
# 1996                                   NaN          3800 RESERVOIR RD NW
# 3236                                   NaN              631 W LUMSDEN RD
# 1223                                   NaN          100 E IRVING PARK RD
# 760                                    NaN           15 E CACTUS WREN DR
# 2543                                   NaN             105 VISTA VIEW DR
# 16       CASCADE MEDICAL TESTING LAB, INC.                  PO BOX 88247
# 403                                    NaN              600 HIGHLAND AVE
# 3231                                   NaN                2650 RIDGE AVE
# 1517                                   NaN          15721 POINSETTIA WAY
# 815                                    NaN                1994 BRAGET ST
# ...                                    ...                           ...
# 2661                                   NaN                 207 W MAIN ST
# 1169                                   NaN                1994 BRAGET ST
# 26             STEWART G WILLOUGHBY DDS PC            8301 S BRANDON AVE
# 825                                    NaN               11414 W PARK PL
# 675                                    NaN         16 W MISSION ST STE V
# 221                                    NaN                2650 RIDGE AVE
# 3339                                   NaN          724 HARRINGTON ST SW
# 1379                                   NaN               11414 W PARK PL
# 1014                                   NaN               1614 S BYRNE RD
# 2931                                   NaN                 207 W MAIN ST
# 2807                                   NaN            945 MIDDLEFIELD RD
# 603                     JAFORD ENTERPRISES                  PO BOX 86028
# 1658                                   NaN                 207 W MAIN ST
# 2109                                   NaN          2736 GOLDEN EAGLE PT
# 2315                                   NaN             316 COURTLAND AVE
# 2480                                   NaN                503 FARRELL DR
# 1343                                   NaN             219 D COMMERCE ST
# 672                                    NaN               33923 124 AVE N
# 2811                                   NaN                 207 W MAIN ST
# 1121                                   NaN               33923 124 AVE N
# 1712                                   NaN                 207 W MAIN ST
# 456                                    NaN              14711 NE 29TH PL
# 871                                    NaN               33923 124 AVE N
# 2547                                   NaN             105 VISTA VIEW DR
# 1138                                   NaN              631 W LUMSDEN RD
# 3092                                   NaN         16435 SEDONA WOODS LN
# 1501                    MONIKA RUKUS, INC.          8901 CONNECTICUT AVE
# 61                                     NaN  2100 E HALLANDALE BEACH BLVD
# 1436                                   NaN                503 FARRELL DR
# 506                                    NaN              14711 NE 29TH PL
#
#      PROV_B_M_A_CITY_NAME PROV_B_M_A_STATE_NAME  PROV_B_M_A_POSTAL_CODE  \
# 735             NASHVILLE                    TN               372043101
# 2935          WESTMINSTER                    CA               926837450
# 625         SANTA BARBARA                    CA               931018498
# 2076               ANKENY                    IA               500232400
# 3127            MILWAUKEE                     0               532243500
# 2068           CLOVERDALE                    CA               954253373
# 2180           COLCHESTER                    VT                       0
# 2154             BELLEVUE                    WA                       0
# 2090                 AVON                    MN                   56310
# 1912    PONTE VEDRA BEACH                     0               320823228
# 780              SYRACUSE                     0               132031652
# 470                DUPONT                    WA                       0
# 3273             WESTBURY                    NY               115902025
# 1127               TOLEDO                    OH               436143464
# 2576          ALBUQUERQUE                    NM               871104186
# 1921              ROSELLE                     0               601722048
# 2574    PONTE VEDRA BEACH                    FL               320823228
# 1826               TOLEDO                    OH               436143464
# 1354          LOS ANGELES                    CA               900361714
# 60              PALO ALTO                     0               943013339
# 1996           WASHINGTON                    DC               200072113
# 3236              BRANDON                     0               335115911
# 1223              ROSELLE                    IL               601722048
# 760               PHOENIX                     0               850204814
# 2543           CLOVERDALE                    CA               954253373
# 16               KENTWOOD                    MI               495180247
# 403               MADISON                    WI               537920001
# 3231             EVANSTON                     0               602011718
# 1517          WESTMINSTER                    CA                       0
# 815                DUPONT                    WA               983279796
# ...                   ...                   ...                     ...
# 2661             PORTLAND                    IN               473712124
# 1169               DUPONT                     0               983279796
# 26                CHICAGO                    IL               606172656
# 825             MILWAUKEE                    WI               532243500
# 675         SANTA BARBARA                    CA               931018498
# 221              EVANSTON                     0               602011718
# 3339           HUTCHINSON                     0                   55350
# 1379            MILWAUKEE                    WI               532243500
# 1014               TOLEDO                    OH               436143464
# 2931             PORTLAND                    IN               473712124
# 2807            PALO ALTO                    CA               943013339
# 603           BATON ROUGE                    LA               708796028
# 1658             PORTLAND                    IN               473712124
# 2109            LAKE MARY                    FL               327467403
# 2315             STAMFORD                    CT                69062269
# 2480            COVINGTON                     0               410113775
# 1343           GREENVILLE                    NC                       0
# 672                  AVON                    MN                       0
# 2811             PORTLAND                    IN               473712124
# 1121                 AVON                    MN                   56310
# 1712             PORTLAND                    IN               473712124
# 456              BELLEVUE                    WA                       0
# 871                  AVON                    MN                   56310
# 2547           CLOVERDALE                    CA               954253373
# 1138              BRANDON                    FL               335115911
# 3092              HOUSTON                    TX               770821658
# 1501          CHEVY CHASE                    MD               208156734
# 61       HALLANDALE BEACH                     0               330093765
# 1436            COVINGTON                     0               410113775
# 506              BELLEVUE                    WA               980077666
#
#      PROV_B_M_A_CNT_CODE_OUT_US  PROV_B_M_A_TELEPHONE_NUMBER  \
# 735                          US                 6.152982e+09
# 2935                         US                 7.148949e+09
# 625                          US                 8.059698e+09
# 2076                         US                 5.159649e+09
# 3127                         US                 4.143591e+09
# 2068                         US                 7.078947e+09
# 2180                         US                 8.029230e+09
# 2154                         US                          NaN
# 2090                         US                 3.202355e+09
# 1912                         US                 9.546557e+09
# 780                          US                 3.158822e+09
# 470                          US                 8.329718e+09
# 3273                         US                 5.162804e+09
# 1127                         US                 4.193858e+09
# 2576                         US                 5.053401e+09
# 1921                         US                 6.304390e+09
# 2574                         US                 9.546557e+09
# 1826                         US                 4.193858e+09
# 1354                         US                 3.238783e+09
# 60                           US                 6.503215e+09
# 1996                         US                 2.024444e+09
# 3236                         US                 8.134139e+09
# 1223                         US                 6.304390e+09
# 760                          US                 6.022492e+09
# 2543                         US                 7.078947e+09
# 16                           US                 6.167340e+09
# 403                          US                 6.086621e+09
# 3231                         US                 8.475701e+09
# 1517                         US                 7.148949e+09
# 815                          US                 8.329718e+09
# ...                         ...                          ...
# 2661                         US                 2.607270e+09
# 1169                         US                 8.329718e+09
# 26                           US                 7.733756e+09
# 825                          US                 4.143591e+09
# 675                          US                 8.059698e+09
# 221                          US                 8.475701e+09
# 3339                         US                 3.202355e+09
# 1379                         US                 4.143591e+09
# 1014                         US                 4.193858e+09
# 2931                         US                 2.607270e+09
# 2807                         US                 6.503215e+09
# 603                          US                 2.252910e+09
# 1658                         US                 2.607270e+09
# 2109                         US                 4.073233e+09
# 2315                         US                 2.033485e+09
# 2480                         US                 8.593313e+09
# 1343                         US                 2.523553e+09
# 672                          US                 3.202355e+09
# 2811                         US                 2.607270e+09
# 1121                         US                 3.202355e+09
# 1712                         US                 2.607270e+09
# 456                          US                          NaN
# 871                          US                 3.202355e+09
# 2547                         US                 7.078947e+09
# 1138                         US                 8.134139e+09
# 3092                         US                 2.814967e+09
# 1501                         US                 3.019870e+09
# 61                           US                 9.544570e+09
# 1436                         US                 8.593313e+09
# 506                          US                          NaN
#
#                       ...                   AUTH_OFF_FRST_NAME  \
# 735                   ...                                  NaN
# 2935                  ...                                  NaN
# 625                   ...                                  NaN
# 2076                  ...                                  NaN
# 3127                  ...                                  NaN
# 2068                  ...                                  NaN
# 2180                  ...                                KEITH
# 2154                  ...                                  NaN
# 2090                  ...                                  NaN
# 1912                  ...                                  NaN
# 780                   ...                                  NaN
# 470                   ...                                  NaN
# 3273                  ...                                  NaN
# 1127                  ...                                  NaN
# 2576                  ...                               LESLIE
# 1921                  ...                                  NaN
# 2574                  ...                                  NaN
# 1826                  ...                                  NaN
# 1354                  ...                                YEFIM
# 60                    ...                                  NaN
# 1996                  ...                                  NaN
# 3236                  ...                                  NaN
# 1223                  ...                                  NaN
# 760                   ...                                  NaN
# 2543                  ...                                  NaN
# 16                    ...                               ROBERT
# 403                   ...                                  NaN
# 3231                  ...                                  NaN
# 1517                  ...                                  NaN
# 815                   ...                                  NaN
# ...                   ...                                  ...
# 2661                  ...                                  NaN
# 1169                  ...                                  NaN
# 26                    ...                              STEWART
# 825                   ...                                  NaN
# 675                   ...                                  NaN
# 221                   ...                                  NaN
# 3339                  ...                                  NaN
# 1379                  ...                                  NaN
# 1014                  ...                                  NaN
# 2931                  ...                                  NaN
# 2807                  ...                                  NaN
# 603                   ...                             SHEVELLE
# 1658                  ...                                  NaN
# 2109                  ...                                  NaN
# 2315                  ...                                  NaN
# 2480                  ...                                  NaN
# 1343                  ...                                  NaN
# 672                   ...                                  NaN
# 2811                  ...                                  NaN
# 1121                  ...                                  NaN
# 1712                  ...                                  NaN
# 456                   ...                                  NaN
# 871                   ...                                  NaN
# 2547                  ...                                  NaN
# 1138                  ...                                  NaN
# 3092                  ...                                  NaN
# 1501                  ...                               MONIKA
# 61                    ...                                  NaN
# 1436                  ...                                  NaN
# 506                   ...                                  NaN
#
#      AUTH_OFF_MIDDLE_NAME AUTH_OFF_TITLE_OR_POSITION  \
# 735                   NaN                        NaN
# 2935                  NaN                        NaN
# 625                   NaN                        NaN
# 2076                  NaN                        NaN
# 3127                  NaN                        NaN
# 2068                  NaN                        NaN
# 2180                   P.         OWNER, AUDIOLOGIST
# 2154                  NaN                        NaN
# 2090                  NaN                        NaN
# 1912                  NaN                        NaN
# 780                   NaN                        NaN
# 470                   NaN                        NaN
# 3273                  NaN                        NaN
# 1127                  NaN                        NaN
# 2576                  NaN  CLINICAL NURSE SPECIALIST
# 1921                  NaN                        NaN
# 2574                  NaN                        NaN
# 1826                  NaN                        NaN
# 1354                  NaN                  PRESIDENT
# 60                    NaN                        NaN
# 1996                  NaN                        NaN
# 3236                  NaN                        NaN
# 1223                  NaN                        NaN
# 760                   NaN                        NaN
# 2543                  NaN                        NaN
# 16                    NaN                  PRESIDENT
# 403                   NaN                        NaN
# 3231                  NaN                        NaN
# 1517                  NaN                        NaN
# 815                   NaN                        NaN
# ...                   ...                        ...
# 2661                  NaN                        NaN
# 1169                  NaN                        NaN
# 26                 GORDON                  PRESIDENT
# 825                   NaN                        NaN
# 675                   NaN                        NaN
# 221                   NaN                        NaN
# 3339                  NaN                        NaN
# 1379                  NaN                        NaN
# 1014                  NaN                        NaN
# 2931                  NaN                        NaN
# 2807                  NaN                        NaN
# 603                 LIESA                        PIC
# 1658                  NaN                        NaN
# 2109                  NaN                        NaN
# 2315                  NaN                        NaN
# 2480                  NaN                        NaN
# 1343                  NaN                        NaN
# 672                   NaN                        NaN
# 2811                  NaN                        NaN
# 1121                  NaN                        NaN
# 1712                  NaN                        NaN
# 456                   NaN                        NaN
# 871                   NaN                        NaN
# 2547                  NaN                        NaN
# 1138                  NaN                        NaN
# 3092                  NaN                        NaN
# 1501                   L.                      OWNER
# 61                    NaN                        NaN
# 1436                  NaN                        NaN
# 506                   NaN                        NaN
#
#       AUTH_OFF_TELEPHONE_NUMBER H_P_T_CODE_1  PROV_LIC_NUM_1  \
# 735                         NaN   1223G0001X            7541
# 2935                        NaN   101YM0800X             NaN
# 625                         NaN   101YM0800X             NaN
# 2076                        NaN   111N00000X            6709
# 3127                        NaN   174400000X        3135-024
# 2068                        NaN   171W00000X         CAOT#12
# 2180               8.029230e+09   231H00000X     15000006649
# 2154                        NaN   208000000X      MD00035709
# 2090                        NaN   101YA0400X          300158
# 1912                        NaN   152W00000X         OPC4176
# 780                         NaN   1041C0700X         R076173
# 470                         NaN   171000000X          109386
# 3273                        NaN   111N00000X         X004348
# 1127                        NaN   225100000X            1919
# 2576               5.053401e+09   364SA2200X          R47327
# 1921                        NaN   225100000X      070-010485
# 2574                        NaN   152W00000X         OPC4176
# 1826                        NaN   225100000X            1919
# 1354               3.236173e+09   343900000X             NaN
# 60                          NaN   2084P0800X           85120
# 1996                        NaN   225X00000X             NaN
# 3236                        NaN   207RS0012X         ME49689
# 1223                        NaN   225100000X      070-008093
# 760                         NaN   111N00000X             757
# 2543                        NaN   171W00000X         CAOT#12
# 16                 6.169566e+09   291U00000X             NaN
# 403                         NaN   183500000X       12743-040
# 3231                        NaN   208000000X             NaN
# 1517                        NaN   101YM0800X             NaN
# 815                         NaN   171000000X          109386
# ...                         ...          ...             ...
# 2661                        NaN   111N00000X       08002013A
# 1169                        NaN   171000000X          109386
# 26                 7.733756e+09   122300000X             NaN
# 825                         NaN   174400000X        3135-024
# 675                         NaN   101YM0800X             NaN
# 221                         NaN   208000000X             NaN
# 3339                        NaN   163W00000X         1158333
# 1379                        NaN   174400000X        3135-024
# 1014                        NaN   225100000X            1919
# 2931                        NaN   111N00000X       08002013A
# 2807                        NaN   2084P0800X           85120
# 603                2.252910e+09   3336C0003X            4058
# 1658                        NaN   111N00000X       08002013A
# 2109                        NaN   225100000X         PT21108
# 2315                        NaN   207RG0100X           38509
# 2480                        NaN   1041C0700X            3339
# 1343                        NaN   103T00000X            1348
# 672                         NaN   101YA0400X          300158
# 2811                        NaN   111N00000X       08002013A
# 1121                        NaN   101YA0400X          300158
# 1712                        NaN   111N00000X       08002013A
# 456                         NaN   208000000X      MD00035709
# 871                         NaN   101YA0400X          300158
# 2547                        NaN   171W00000X         CAOT#12
# 1138                        NaN   207RS0012X         ME49689
# 3092                        NaN   152W00000X          5499TG
# 1501               3.019870e+09   101YM0800X            8641
# 61                          NaN   1223G0001X         FLA5717
# 1436                        NaN   1041C0700X            3339
# 506                         NaN   208000000X      MD00035709
#
#      PROV_LIC_NUM_STATE_CODE_1 H_P_P_T_SWITCH_1 PRIMARY_TAXONOMY  \
# 735                         TN                Y       1223G0001X
# 2935                       NaN                Y       101YM0800X
# 625                        NaN                Y       101YM0800X
# 2076                        IA                Y       111N00000X
# 3127                        WI                Y       174400000X
# 2068                        CA                Y       171W00000X
# 2180                        NY                Y       231H00000X
# 2154                        WA                Y       208000000X
# 2090                        MN                X       101YA0400X
# 1912                        FL                Y       152W00000X
# 780                         NY                Y       1041C0700X
# 470                         TX                Y       171000000X
# 3273                        NY                Y       111N00000X
# 1127                        OH                Y       225100000X
# 2576                        NM                Y       364SA2200X
# 1921                        IL                Y       225100000X
# 2574                        FL                Y       152W00000X
# 1826                        OH                Y       225100000X
# 1354                       NaN                Y       343900000X
# 60                          NM                N       2084P0800X
# 1996                        DC                Y       225X00000X
# 3236                        FL                N       207RP1001X
# 1223                        IL                Y       225100000X
# 760                         AZ                Y       111N00000X
# 2543                        CA                Y       171W00000X
# 16                         NaN                Y       291U00000X
# 403                         WI                X       183500000X
# 3231                        IL                Y       208000000X
# 1517                       NaN                Y       101YM0800X
# 815                         TX                Y       171000000X
# ...                        ...              ...              ...
# 2661                        IN                Y       111N00000X
# 1169                        TX                Y       171000000X
# 26                          IL                Y       122300000X
# 825                         WI                Y       174400000X
# 675                        NaN                Y       101YM0800X
# 221                         IL                Y       208000000X
# 3339                        MN                Y       163W00000X
# 1379                        WI                Y       174400000X
# 1014                        OH                Y       225100000X
# 2931                        IN                Y       111N00000X
# 2807                        NM                N       2084P0800X
# 603                         LA                Y       3336C0003X
# 1658                        IN                Y       111N00000X
# 2109                        FL                Y       225100000X
# 2315                        CT                Y       207RG0100X
# 2480                        KY                Y       1041C0700X
# 1343                        NC                Y       103T00000X
# 672                         MN                X       101YA0400X
# 2811                        IN                Y       111N00000X
# 1121                        MN                X       101YA0400X
# 1712                        IN                Y       111N00000X
# 456                         WA                Y       208000000X
# 871                         MN                X       101YA0400X
# 2547                        CA                Y       171W00000X
# 1138                        FL                N       207RP1001X
# 3092                        TX                Y       152W00000X
# 1501                        MD                Y       101YM0800X
# 61                          FL                Y       1223G0001X
# 1436                        KY                Y       1041C0700X
# 506                         WA                Y       208000000X
#
#                                    SPECDESC
# 735                        General Practice
# 2935                          Mental Health
# 625                           Mental Health
# 2076                           Chiropractor
# 3127                             Specialist
# 2068                             Contractor
# 2180                            Audiologist
# 2154                             Pediatrics
# 2090     Addiction (Substance Use Disorder)
# 1912                            Optometrist
# 780                                Clinical
# 470           Military Health Care Provider
# 3273                           Chiropractor
# 1127                     Physical Therapist
# 2576                           Adult Health
# 1921                     Physical Therapist
# 2574                            Optometrist
# 1826                     Physical Therapist
# 1354  Non-emergency Medical Transport (VAN)
# 60                               Psychiatry
# 1996                 Occupational Therapist
# 3236                                      0
# 1223                     Physical Therapist
# 760                            Chiropractor
# 2543                                      0
# 16              Clinical Medical Laboratory
# 403                              Pharmacist
# 3231                                      0
# 1517                                      0
# 815           Military Health Care Provider
# ...                                     ...
# 2661                           Chiropractor
# 1169          Military Health Care Provider
# 26                                  Dentist
# 825                              Specialist
# 675                                       0
# 221                              Pediatrics
# 3339                       Registered Nurse
# 1379                             Specialist
# 1014                     Physical Therapist
# 2931                           Chiropractor
# 2807                             Psychiatry
# 603               Community/Retail Pharmacy
# 1658                           Chiropractor
# 2109                     Physical Therapist
# 2315                       Gastroenterology
# 2480                               Clinical
# 1343                           Psychologist
# 672                                       0
# 2811                           Chiropractor
# 1121     Addiction (Substance Use Disorder)
# 1712                           Chiropractor
# 456                              Pediatrics
# 871      Addiction (Substance Use Disorder)
# 2547                             Contractor
# 1138                      Pulmonary Disease
# 3092                            Optometrist
# 1501                                      0
# 61                         General Practice
# 1436                               Clinical
# 506                              Pediatrics
#
# [3396 rows x 29 columns]

# %%
file1 = "test2.csv"
input = pd.read_csv(file1, delimiter=",")

# %%
input
# Out:
#    NPI                         PROVIDERNAME  ENTITY_TYPE_CODE  \
# 0  NaN                   MONIKA RUKUS, INC.                 2
# 1  NaN                         MOSS, PAUL R                 1
# 2  NaN               SCHMIT, EDWARD CHARLES                 1
# 3  NaN                        VO, CHRISTINE                 1
# 4  NaN                     SANCHEZ, ROBERTO                 1
# 5  NaN                 WEBSTER, JOHN THOMAS                 1
# 6  NaN  ADIRONDACK AUDIOLOGY ASSOCIATES, PC                 2
# 7  NaN                   RUTAR, STACIE HOPE                 1
# 8  NaN      ONCOLOGY HEMATOLOGY ASSOCIATION                 2
# 9  NaN                FISCHER, CINDY JOLENE                 1
#
#              P_O_N_LEGAL_BUSINESS_NAME             P_F_L_B_M_ADDRESS  \
# 0                   MONIKA RUKUS, INC.          8901 CONNECTICUT AVE
# 1                                  NaN                1932 SW 3RD ST
# 2                                  NaN                 207 W MAIN ST
# 3                                  NaN          15721 POINSETTIA WAY
# 4                                  NaN          1755 AVE PAZ GRANELA
# 5                                  NaN               1614 S BYRNE RD
# 6  ADIRONDACK AUDIOLOGY ASSOCIATES, PC  356 MOUNTAIN VIEW DR STE 101
# 7                                  NaN                503 FARRELL DR
# 8      ONCOLOGY HEMATOLOGY ASSOCIATION                2 HOT METAL ST
# 9                                  NaN          724 HARRINGTON ST SW
#
#   PROV_B_M_A_CITY_NAME PROV_B_M_A_STATE_NAME  PROV_B_M_A_POSTAL_CODE  \
# 0          CHEVY CHASE                    MD               208156734
# 1               ANKENY                    IA               500232400
# 2             PORTLAND                    IN               473712124
# 3          WESTMINSTER                    CA               926837450
# 4             SAN JUAN                    PR                 9213630
# 5               TOLEDO                    OH               436143464
# 6           COLCHESTER                    VT                54465986
# 7            COVINGTON                    KY               410113775
# 8           PITTSBURGH                    PA               152032348
# 9           HUTCHINSON                    MN                   55350
#
#   PROV_B_M_A_CNT_CODE_OUT_US  PROV_B_M_A_TELEPHONE_NUMBER  \
# 0                         US                   3019869999
# 1                         US                   5159649114
# 2                         US                   2607269661
# 3                         US                   7148949078
# 4                         US                   7877928200
# 5                         US                   4193857755
# 6                         US                   8029229545
# 7                         US                   8593313292
# 8                         US                   4124327706
# 9                         US                   3202354613
#
#                        ...                      AUTH_OFF_FRST_NAME  \
# 0                      ...                                  MONIKA
# 1                      ...                                     NaN
# 2                      ...                                     NaN
# 3                      ...                                     NaN
# 4                      ...                                     NaN
# 5                      ...                                     NaN
# 6                      ...                                   KEITH
# 7                      ...                                     NaN
# 8                      ...                                 RICHARD
# 9                      ...                                     NaN
#
#   AUTH_OFF_MIDDLE_NAME AUTH_OFF_TITLE_OR_POSITION  AUTH_OFF_TELEPHONE_NUMBER  \
# 0                   L.                      OWNER               3.019870e+09
# 1                  NaN                        NaN                        NaN
# 2                  NaN                        NaN                        NaN
# 3                  NaN                        NaN                        NaN
# 4                  NaN                        NaN                        NaN
# 5                  NaN                        NaN                        NaN
# 6                   P.         OWNER, AUDIOLOGIST               8.029230e+09
# 7                  NaN                        NaN                        NaN
# 8                    P                 CONTROLLER               4.124737e+09
# 9                  NaN                        NaN                        NaN
#
#   H_P_T_CODE_1  PROV_LIC_NUM_1 PROV_LIC_NUM_STATE_CODE_1 H_P_P_T_SWITCH_1  \
# 0   101YM0800X            8641                        MD                Y
# 1   111N00000X            6709                        IA                Y
# 2   111N00000X       08002013A                        IN                Y
# 3   101YM0800X             NaN                       NaN                Y
# 4   1223G0001X            1572                        PR                Y
# 5   225100000X            1919                        OH                Y
# 6   231H00000X     15000006649                        NY                Y
# 7   1041C0700X            3339                        KY                Y
# 8   332B00000X             NaN                       NaN                Y
# 9   163W00000X         1158333                        MN                Y
#
#   PRIMARY_TAXONOMY                                      SPECDESC
# 0       101YM0800X                                 Mental Health
# 1       111N00000X                                  Chiropractor
# 2       111N00000X                                  Chiropractor
# 3       101YM0800X                                 Mental Health
# 4       1223G0001X                              General Practice
# 5       225100000X                            Physical Therapist
# 6       231H00000X                                   Audiologist
# 7       1041C0700X                                      Clinical
# 8       332B00000X  Durable Medical Equipment & Medical Supplies
# 9       163W00000X                              Registered Nurse
#
# [10 rows x 29 columns]

# %%
X_1 = input[['ENTITY_TYPE_CODE','PROVIDERNAME', 'PROV_B_M_A_STATE_NAME', 'PROV_B_M_A_POSTAL_CODE', 'SPECDESC','PROV_B_P_B_P_LOC_ADD_TEL_NUM','PROV_B_M_A_CITY_NAME','PRIMARY_TAXONOMY']].values
X[0:3]
# Out:
# array([[1, 19, 2, 954253373, 9, 7078947409, 10, 13],
#        [1, 44, 10, 672083714, 15, 3169460990, 48, 6],
#        [2, 30, 13, 208156734, 16, 3019869999, 8, 1]], dtype=object)

# %%
from sklearn import preprocessing

le_PROVIDERNAME = preprocessing.LabelEncoder()
le_PROVIDERNAME.fit(np.unique(my_data["PROVIDERNAME"]))
X_1[:,1] = le_PROVIDERNAME.transform(X_1[:,1]) 

le_STATE_NAME = preprocessing.LabelEncoder()
le_STATE_NAME.fit(np.unique(my_data["PROV_B_M_A_STATE_NAME"]))
X_1[:,2] = le_STATE_NAME.transform(X_1[:,2]) 

le_SPECDESC = preprocessing.LabelEncoder()
le_SPECDESC.fit(np.unique(my_data["SPECDESC"]))
X_1[:,4] = le_SPECDESC.transform(X_1[:,4]) 

le_CITY_NAME = preprocessing.LabelEncoder()
le_CITY_NAME.fit(np.unique(my_data["PROV_B_M_A_CITY_NAME"]))
X_1[:,6] = le_CITY_NAME.transform(X_1[:,6]) 


le_PRIMARY_TAXONOMY = preprocessing.LabelEncoder()
le_PRIMARY_TAXONOMY.fit(np.unique(my_data["PRIMARY_TAXONOMY"]))
X_1[:,7] = le_PRIMARY_TAXONOMY.transform(X_1[:,7])

# %%
predTree = npiTree.predict(X_1)

# %%
predTree
# Out:
# array([1003981614, 1164597779, 1124193735, 1053485896, 1427122274,
#        1205901824, 1841365467, 1295800811, 1790850303, 1851465611],
#       dtype=int64)

# %%
df = pd.DataFrame (predTree)

#filepath = 'file.txt'
#df.savetxt(filepath, index=False)

# %%
np.savetxt(r'np1.txt', df.values, fmt='%d')
